# %% [markdown]
# # Rapport - labb 3

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import LABB3
from LABB3 import x,y,x_point,y_point,x_val,x_under,y_under, x_over,y_over,f,g,h,diff_percent_f,diff_percent_g,diff_percent_h
from LABB3 import plot_data_punkter
plot_data_punkter(x_over,y_over,x_under,y_under,x_point,y_point)

# %% [markdown]
# Här plotas datan ut med min funktion y=-x
#
# Funktionen Y=-X delar här på de 2 klusterna och klassificerar alla punkter ovanför linjen med klass 1 och alla punkter under linjen till klass 0.

# %%
from LABB3 import plot_classification_results
plot_classification_results(x,y,x_point,y_point,x_val,f,g,h,diff_percent_f,diff_percent_g,diff_percent_h)

# %% [markdown]
# ### Skillnader mellan olika funktioner
#
# Det vi kan se i grafen ovan är att funktionerna f(x) och g(x) klassificerar datan nästan exakt som funktion y=-x. Funktionen h(x) däremot klassificerar 99% av datan annorlunda jämfört med y=-x. Då lutningen (k) är positiv och har en brant stigning gör det att alla punkter till vänster hamnar ovanför linjen och alla punkter till höger om linjen hamnar under. Klassen på punkterna blir tvärtom gentemot de andra funktionera med undantag för outliers i klustrerna.

# %% [markdown]
# ### Slutsats
#
# När datapunkternas struktur är i separerbara klusters så är det att föredra en linje som går mitt emellan klustrerna. Det finns då en stor mängd linjer som kan dras mellan dessa klustrerna med olika k och m värden som kan ge samma resultat. Om vi istället tar fram en linje med största marginal till de närmsta punkterna mellan klusterna (som en SVM) så finns det bara en linje. Vi kan anta att så länge vi balanserat en linje mellan klustrerna med största marginal så har vi generaliserat datan så bra vi kan.
